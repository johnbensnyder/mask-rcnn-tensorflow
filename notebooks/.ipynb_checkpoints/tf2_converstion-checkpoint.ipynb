# %%
import sys
sys.path.append('../MaskRCNN/')
import itertools
import numpy as np
import shutil
import cv2
import six
assert six.PY3, "FasterRCNN requires Python 3!"
import tensorflow.compat.v1 as tf
'''from tensorflow.keras.mixed_precision import experimental as mixed_precision
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_policy(policy)'''
tf.disable_eager_execution()
import tqdm
import time
import subprocess
import os

import tensorpack_viz as tpviz
from tensorpack_tfutils import get_tf_version_tuple, get_model_loader
from tensorpack_utils import fix_rng_seed
from tensorpack_input_source import QueueInput
from tensorpack_train import TrainConfig
from tensorpack_interface import launch_train_with_config
from tensorpack_callbacks import PeriodicCallback, EnableCallbackIf, ModelSaver,\
                                 GraphProfiler, PeakMemoryTracker, EstimatedTimeLeft, SessionRunTimeout, \
                                 MovingAverageSummary, ProgressBar, MergeAllSummaries, RunUpdateOps, ScheduledHyperParamSetter
import tensorpack_logger as logger


from dataset import DetectionDataset
from config import finalize_configs, config as cfg
from data import get_eval_dataflow, get_train_dataflow, get_batch_train_dataflow
from eval import DetectionResult, predict_image, multithread_predict_dataflow, EvalCallback
from viz import draw_annotation, draw_final_outputs, draw_predictions, draw_proposal_recall
from performance import ThroughputTracker, humanize_float
from model.generalized_rcnn import ResNetFPNModel
import horovod.tensorflow as hvd

config = ['MODE_MASK=True',
'MODE_FPN=True',
'DATA.BASEDIR=/workspace/shared_workspace/data/coco/coco/',
'DATA.TRAIN=["train2017"]',
'DATA.VAL=("val2017",)',
'TRAIN.BATCH_SIZE_PER_GPU=8',
'TRAIN.LR_EPOCH_SCHEDULE=[(8, 0.1), (10, 0.01), (12, None)]',
'TRAIN.EVAL_PERIOD=24',
'TRAIN.BACKBONE_NCHW=False',
'TRAIN.FPN_NCHW=False',
'TRAIN.RPN_NCHW=False',
'TRAIN.MASK_NCHW=False',
'RPN.TOPK_PER_IMAGE=True',
'PREPROC.PREDEFINED_PADDING=False',
'BACKBONE.WEIGHTS=/workspace/shared_workspace/data/coco/pretrained-models/ImageNet-R50-AlignPadding.npz',
'BACKBONE.NORM=FreezeBN',
'TRAIN.WARMUP_INIT_LR=0.000416666666667',
'FRCNN.BBOX_REG_WEIGHTS=[20., 20., 10., 10.]',
'TRAINER=horovod']

# %%
os.environ['TENSORPACK_FP16']='1'
os.environ['TF_CUDNN_USE_AUTOTUNE']='0'
os.environ['TF_ENABLE_NHWC']='1'

# %%
cfg.update_args(config)

# %%
MODEL = ResNetFPNModel(True)

# %%
DetectionDataset()

# %%
is_horovod = cfg.TRAINER == 'horovod'

# %%
hvd.init()

# %%
finalize_configs(is_training=False)
# Out:
# [0819 13:53:22 @config.py:285] Config: ------------------------------------------
# {'BACKBONE': {'FREEZE_AFFINE': False,
#               'FREEZE_AT': 2,
#               'NORM': 'FreezeBN',
#               'RESNET_NUM_BLOCKS': [3, 4, 6, 3],
#               'STRIDE_1X1': False,
#               'TF_PAD_MODE': False,
#               'WEIGHTS': '/workspace/shared_workspace/data/coco/pretrained-models/ImageNet-R50-AlignPadding.npz'},
#  'DATA': {'BASEDIR': '/workspace/shared_workspace/data/coco/coco/',
#           'CLASS_NAMES': ['BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
#                           'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign',
#                           'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
#                           'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag',
#                           'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite',
#                           'baseball bat', 'baseball glove', 'skateboard', 'surfboard',
#                           'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon',
#                           'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot',
#                           'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant',
#                           'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
#                           'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink',
#                           'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear',
#                           'hair drier', 'toothbrush'],
#           'NUM_CATEGORY': 80,
#           'NUM_CLASS': 81,
#           'TRAIN': ['train2017'],
#           'VAL': ('val2017',)},
#  'FPN': {'ANCHOR_STRIDES': (4, 8, 16, 32, 64),
#          'BOXCLASS_CONV_HEAD_DIM': 256,
#          'BOXCLASS_FC_HEAD_DIM': 1024,
#          'BOXCLASS_HEAD_FUNC': 'boxclass_2fc_head',
#          'MRCNN_HEAD_FUNC': 'maskrcnn_up4conv_head',
#          'NORM': 'None',
#          'NUM_CHANNEL': 256,
#          'PROPOSAL_MODE': 'Level',
#          'RESOLUTION_REQUIREMENT': 32},
#  'FRCNN': {'BATCH_PER_IM': 512,
#            'BBOX_REG_WEIGHTS': [20.0, 20.0, 10.0, 10.0],
#            'FG_RATIO': 0.25,
#            'FG_THRESH': 0.5},
#  'MODE_FPN': True,
#  'MODE_MASK': True,
#  'MRCNN': {'HEAD_DIM': 256},
#  'PREPROC': {'MAX_SIZE': 1344.0,
#              'PADDING_SHAPES': [(800, 1000), (800, 1200), (800, 1350)],
#              'PIXEL_MEAN': [123.675, 116.28, 103.53],
#              'PIXEL_STD': [58.395, 57.12, 57.375],
#              'PREDEFINED_PADDING': False,
#              'TEST_SHORT_EDGE_SIZE': 800,
#              'TRAIN_SHORT_EDGE_SIZE': [800, 800]},
#  'RPN': {'ANCHOR_RATIOS': (0.5, 1.0, 2.0),
#          'ANCHOR_SIZES': (32, 64, 128, 256, 512),
#          'ANCHOR_STRIDE': 16,
#          'BATCH_PER_IM': 256,
#          'CROWD_OVERLAP_THRESH': 9.99,
#          'FG_RATIO': 0.5,
#          'HEAD_DIM': 1024,
#          'MIN_SIZE': 0.1,
#          'NEGATIVE_ANCHOR_THRESH': 0.3,
#          'NUM_ANCHOR': 15,
#          'POSITIVE_ANCHOR_THRESH': 0.7,
#          'PROPOSAL_NMS_THRESH': 0.7,
#          'SLOW_ACCURATE_MASK': True,
#          'TEST_PER_LEVEL_NMS_TOPK': 1000,
#          'TEST_POST_NMS_TOPK': 1000,
#          'TEST_PRE_NMS_TOPK': 6000,
#          'TOPK_PER_IMAGE': True,
#          'TRAIN_PER_LEVEL_NMS_TOPK': 2000,
#          'TRAIN_POST_NMS_TOPK': 2000,
#          'TRAIN_PRE_NMS_TOPK': 12000,
#          'UNQUANTIZED_ANCHOR': True},
#  'TEST': {'BOX_TARGET': 0.377,
#           'FRCNN_NMS_THRESH': 0.5,
#           'MASK_TARGET': 0.339,
#           'RESULTS_PER_IM': 100,
#           'RESULT_SCORE_THRESH': 0.05,
#           'RESULT_SCORE_THRESH_VIS': 0.3},
#  'TRAIN': {'BACKBONE_NCHW': False,
#            'BASE_LR': 0.00125,
#            'BATCH_SIZE_PER_GPU': 4,
#            'EVAL_PERIOD': 24,
#            'FPN_NCHW': False,
#            'GRADIENT_CLIP': 0,
#            'LR_EPOCH_SCHEDULE': [(8, 0.1), (10, 0.01), (12, None)],
#            'MASK_NCHW': False,
#            'NUM_GPUS': 1,
#            'RPN_NCHW': False,
#            'SEED': 1234,
#            'SHOULD_STOP': False,
#            'STARTING_EPOCH': 1,
#            'WARMUP_INIT_LR': 0.000416666666667,
#            'WARMUP_STEPS': 1000,
#            'WEIGHT_DECAY': 0.0001},
#  'TRAINER': 'horovod'}

# %%
cfg.TRAIN.EVAL_PERIOD = 1
tf.set_random_seed(cfg.TRAIN.SEED)
fix_rng_seed(cfg.TRAIN.SEED*hvd.rank())
np.random.seed(cfg.TRAIN.SEED)

# %%
images_per_epoch = 120000
images_per_step = cfg.TRAIN.NUM_GPUS * cfg.TRAIN.BATCH_SIZE_PER_GPU
steps_per_epoch = images_per_epoch // images_per_step
batch_size_lr_factor = images_per_step # The LR is defined for bs=1 and then scaled linearly with the batch size
base_lr_adjusted_for_bs = cfg.TRAIN.BASE_LR * batch_size_lr_factor

# %%
# Warmup LR schedule is step based
warmup_start_step = 0
warmup_end_step = cfg.TRAIN.WARMUP_STEPS
warmup_start_lr = cfg.TRAIN.WARMUP_INIT_LR*8
warmup_end_lr = base_lr_adjusted_for_bs
warmup_schedule = [(warmup_start_step, warmup_start_lr), (warmup_end_step, warmup_end_lr)]

# %%
warmup_end_epoch = cfg.TRAIN.WARMUP_STEPS * 1. / steps_per_epoch
training_start_epoch = int(warmup_end_epoch + 0.5)
lr_schedule = [(training_start_epoch, base_lr_adjusted_for_bs)]

# %%
max_epoch = None
for epoch, scheduled_lr_multiplier in cfg.TRAIN.LR_EPOCH_SCHEDULE:
    if scheduled_lr_multiplier is None:
        max_epoch = epoch # Training end is indicated by a lr_multiplier of None
        break

    absolute_lr = base_lr_adjusted_for_bs * scheduled_lr_multiplier
    lr_schedule.append((epoch, absolute_lr))

# %%
train_dataflow = get_batch_train_dataflow(cfg.TRAIN.BATCH_SIZE_PER_GPU)
# Out:
# In train dataflow
# loading annotations into memory...
# Done (t=17.47s)
# creating index...
# index created!
# [0819 13:53:40 @dataset.py:50] Instances loaded from /workspace/shared_workspace/data/coco/coco/annotations/instances_train2017.json.
# 100%|██████████| 118287/118287 [00:18<00:00, 6233.73it/s]
# [0819 13:53:59 @tensorpack_utils.py:349] Load Load annotations for train2017 finished, time:19.0846sec.
# Done loading roidbs
# [0819 13:54:03 @data.py:618] Filtered 1021 images which contain no non-crowd groudtruth boxes. Total #images for training: 117266
# Batching roidbs
# Done batching roidbs

# %%
logdir = '/workspace/shared_workspace/logs'

# %%
callbacks = [
    # linear warmup
    ScheduledHyperParamSetter(
        'learning_rate', warmup_schedule, interp='linear', step_based=True),
    ScheduledHyperParamSetter('learning_rate', lr_schedule),
    EstimatedTimeLeft(median=True),
    SessionRunTimeout(60000).set_chief_only(True),   # 1 minute timeout
]
'''PeriodicCallback(
        ModelSaver(max_to_keep=10, keep_checkpoint_every_n_hours=1),
        every_k_epochs=20),
        PeakMemoryTracker(),'''

callbacks.extend([
    EvalCallback(dataset, *MODEL.get_inference_tensor_names(), logdir, 1, a_sync=True) #cfg.TRAIN.BATCH_SIZE_PER_GPU)
    for dataset in cfg.DATA.VAL
])


callbacks.append(ThroughputTracker(cfg.TRAIN.BATCH_SIZE_PER_GPU*cfg.TRAIN.NUM_GPUS,
                                   images_per_epoch,
                                   trigger_every_n_steps=2000,
                                   log_fn=logger.info))

# modify profiler callback

# %%
session_init = get_model_loader(cfg.BACKBONE.WEIGHTS)

# %%
traincfg = TrainConfig(
            model=MODEL,
            data=QueueInput(train_dataflow),
            callbacks=callbacks,
            extra_callbacks=[
               MovingAverageSummary(),
               ProgressBar(),
               MergeAllSummaries(period=250),
               RunUpdateOps()
            ],
            steps_per_epoch=steps_per_epoch,
            max_epoch=max_epoch,
            session_init=session_init,
            session_config=None,
            starting_epoch=cfg.TRAIN.STARTING_EPOCH
        )

# %%
launch_train_with_config(traincfg)
# Out:
# [0819 13:54:05 @tensorpack_input_source.py:238] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# [0819 13:54:05 @tensorpack_models.py:181] conv0 input: [None, None, None, 3]
# Use channels_last data format
# WARNING:tensorflow:From ../MaskRCNN/tensorpack_models.py:448: Layer.apply (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# [0819 13:54:05 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] conv0 output: [None, None, None, 64]
# [0819 13:54:06 @tensorpack_models.py:181] pool0 input: [None, None, None, 64]
# [0819 13:54:06 @tensorpack_models.py:189] pool0 output: [None, None, None, 64]
# [0819 13:54:06 @tensorpack_models.py:181] group0/block0/conv1 input: [None, None, None, 64]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group0/block0/conv1 output: [None, None, None, 64]
# [0819 13:54:06 @tensorpack_models.py:181] group0/block0/conv2 input: [None, None, None, 64]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group0/block0/conv2 output: [None, None, None, 64]
# [0819 13:54:06 @tensorpack_models.py:181] group0/block0/conv3 input: [None, None, None, 64]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group0/block0/conv3 output: [None, None, None, 256]
# [0819 13:54:06 @tensorpack_models.py:181] group0/block0/convshortcut input: [None, None, None, 64]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group0/block0/convshortcut output: [None, None, None, 256]
# [0819 13:54:06 @tensorpack_models.py:181] group0/block1/conv1 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group0/block1/conv1 output: [None, None, None, 64]
# [0819 13:54:06 @tensorpack_models.py:181] group0/block1/conv2 input: [None, None, None, 64]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group0/block1/conv2 output: [None, None, None, 64]
# [0819 13:54:06 @tensorpack_models.py:181] group0/block1/conv3 input: [None, None, None, 64]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group0/block1/conv3 output: [None, None, None, 256]
# [0819 13:54:06 @tensorpack_models.py:181] group0/block2/conv1 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group0/block2/conv1 output: [None, None, None, 64]
# [0819 13:54:06 @tensorpack_models.py:181] group0/block2/conv2 input: [None, None, None, 64]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group0/block2/conv2 output: [None, None, None, 64]
# [0819 13:54:06 @tensorpack_models.py:181] group0/block2/conv3 input: [None, None, None, 64]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group0/block2/conv3 output: [None, None, None, 256]
# [0819 13:54:06 @tensorpack_models.py:181] group1/block0/conv1 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group1/block0/conv1 output: [None, None, None, 128]
# [0819 13:54:06 @tensorpack_models.py:181] group1/block0/conv2 input: [None, None, None, 128]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group1/block0/conv2 output: [None, None, None, 128]
# [0819 13:54:06 @tensorpack_models.py:181] group1/block0/conv3 input: [None, None, None, 128]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group1/block0/conv3 output: [None, None, None, 512]
# [0819 13:54:06 @tensorpack_models.py:181] group1/block0/convshortcut input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group1/block0/convshortcut output: [None, None, None, 512]
# [0819 13:54:06 @tensorpack_models.py:181] group1/block1/conv1 input: [None, None, None, 512]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group1/block1/conv1 output: [None, None, None, 128]
# [0819 13:54:06 @tensorpack_models.py:181] group1/block1/conv2 input: [None, None, None, 128]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group1/block1/conv2 output: [None, None, None, 128]
# [0819 13:54:06 @tensorpack_models.py:181] group1/block1/conv3 input: [None, None, None, 128]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group1/block1/conv3 output: [None, None, None, 512]
# [0819 13:54:06 @tensorpack_models.py:181] group1/block2/conv1 input: [None, None, None, 512]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group1/block2/conv1 output: [None, None, None, 128]
# [0819 13:54:06 @tensorpack_models.py:181] group1/block2/conv2 input: [None, None, None, 128]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:06 @tensorpack_models.py:189] group1/block2/conv2 output: [None, None, None, 128]
# [0819 13:54:06 @tensorpack_models.py:181] group1/block2/conv3 input: [None, None, None, 128]
# Use channels_last data format
# [0819 13:54:06 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:07 @tensorpack_models.py:189] group1/block2/conv3 output: [None, None, None, 512]
# [0819 13:54:07 @tensorpack_models.py:181] group1/block3/conv1 input: [None, None, None, 512]
# Use channels_last data format
# [0819 13:54:07 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:07 @tensorpack_models.py:189] group1/block3/conv1 output: [None, None, None, 128]
# [0819 13:54:07 @tensorpack_models.py:181] group1/block3/conv2 input: [None, None, None, 128]
# Use channels_last data format
# [0819 13:54:07 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:07 @tensorpack_models.py:189] group1/block3/conv2 output: [None, None, None, 128]
# [0819 13:54:07 @tensorpack_models.py:181] group1/block3/conv3 input: [None, None, None, 128]
# Use channels_last data format
# [0819 13:54:07 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:07 @tensorpack_models.py:189] group1/block3/conv3 output: [None, None, None, 512]
# [0819 13:54:07 @tensorpack_models.py:181] group2/block0/conv1 input: [None, None, None, 512]
# Use channels_last data format
# [0819 13:54:07 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:07 @tensorpack_models.py:189] group2/block0/conv1 output: [None, None, None, 256]
# [0819 13:54:07 @tensorpack_models.py:181] group2/block0/conv2 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:07 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:07 @tensorpack_models.py:189] group2/block0/conv2 output: [None, None, None, 256]
# [0819 13:54:07 @tensorpack_models.py:181] group2/block0/conv3 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:07 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:07 @tensorpack_models.py:189] group2/block0/conv3 output: [None, None, None, 1024]
# [0819 13:54:07 @tensorpack_models.py:181] group2/block0/convshortcut input: [None, None, None, 512]
# Use channels_last data format
# [0819 13:54:07 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:07 @tensorpack_models.py:189] group2/block0/convshortcut output: [None, None, None, 1024]
# [0819 13:54:07 @tensorpack_models.py:181] group2/block1/conv1 input: [None, None, None, 1024]
# Use channels_last data format
# [0819 13:54:07 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:07 @tensorpack_models.py:189] group2/block1/conv1 output: [None, None, None, 256]
# [0819 13:54:07 @tensorpack_models.py:181] group2/block1/conv2 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:07 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:07 @tensorpack_models.py:189] group2/block1/conv2 output: [None, None, None, 256]
# [0819 13:54:07 @tensorpack_models.py:181] group2/block1/conv3 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:07 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:07 @tensorpack_models.py:189] group2/block1/conv3 output: [None, None, None, 1024]
# [0819 13:54:07 @tensorpack_models.py:181] group2/block2/conv1 input: [None, None, None, 1024]
# Use channels_last data format
# [0819 13:54:07 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:07 @tensorpack_models.py:189] group2/block2/conv1 output: [None, None, None, 256]
# [0819 13:54:07 @tensorpack_models.py:181] group2/block2/conv2 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:07 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:07 @tensorpack_models.py:189] group2/block2/conv2 output: [None, None, None, 256]
# [0819 13:54:07 @tensorpack_models.py:181] group2/block2/conv3 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:07 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:07 @tensorpack_models.py:189] group2/block2/conv3 output: [None, None, None, 1024]
# [0819 13:54:07 @tensorpack_models.py:181] group2/block3/conv1 input: [None, None, None, 1024]
# Use channels_last data format
# [0819 13:54:07 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:07 @tensorpack_models.py:189] group2/block3/conv1 output: [None, None, None, 256]
# [0819 13:54:07 @tensorpack_models.py:181] group2/block3/conv2 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:07 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:07 @tensorpack_models.py:189] group2/block3/conv2 output: [None, None, None, 256]
# [0819 13:54:07 @tensorpack_models.py:181] group2/block3/conv3 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:07 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:08 @tensorpack_models.py:189] group2/block3/conv3 output: [None, None, None, 1024]
# [0819 13:54:08 @tensorpack_models.py:181] group2/block4/conv1 input: [None, None, None, 1024]
# Use channels_last data format
# [0819 13:54:08 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:08 @tensorpack_models.py:189] group2/block4/conv1 output: [None, None, None, 256]
# [0819 13:54:08 @tensorpack_models.py:181] group2/block4/conv2 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:08 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:08 @tensorpack_models.py:189] group2/block4/conv2 output: [None, None, None, 256]
# [0819 13:54:08 @tensorpack_models.py:181] group2/block4/conv3 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:08 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:08 @tensorpack_models.py:189] group2/block4/conv3 output: [None, None, None, 1024]
# [0819 13:54:08 @tensorpack_models.py:181] group2/block5/conv1 input: [None, None, None, 1024]
# Use channels_last data format
# [0819 13:54:08 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:08 @tensorpack_models.py:189] group2/block5/conv1 output: [None, None, None, 256]
# [0819 13:54:08 @tensorpack_models.py:181] group2/block5/conv2 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:08 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:08 @tensorpack_models.py:189] group2/block5/conv2 output: [None, None, None, 256]
# [0819 13:54:08 @tensorpack_models.py:181] group2/block5/conv3 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:08 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:08 @tensorpack_models.py:189] group2/block5/conv3 output: [None, None, None, 1024]
# [0819 13:54:08 @tensorpack_models.py:181] group3/block0/conv1 input: [None, None, None, 1024]
# Use channels_last data format
# [0819 13:54:08 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:08 @tensorpack_models.py:189] group3/block0/conv1 output: [None, None, None, 512]
# [0819 13:54:08 @tensorpack_models.py:181] group3/block0/conv2 input: [None, None, None, 512]
# Use channels_last data format
# [0819 13:54:08 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:08 @tensorpack_models.py:189] group3/block0/conv2 output: [None, None, None, 512]
# [0819 13:54:08 @tensorpack_models.py:181] group3/block0/conv3 input: [None, None, None, 512]
# Use channels_last data format
# [0819 13:54:08 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:08 @tensorpack_models.py:189] group3/block0/conv3 output: [None, None, None, 2048]
# [0819 13:54:08 @tensorpack_models.py:181] group3/block0/convshortcut input: [None, None, None, 1024]
# Use channels_last data format
# [0819 13:54:08 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:08 @tensorpack_models.py:189] group3/block0/convshortcut output: [None, None, None, 2048]
# [0819 13:54:08 @tensorpack_models.py:181] group3/block1/conv1 input: [None, None, None, 2048]
# Use channels_last data format
# [0819 13:54:08 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:08 @tensorpack_models.py:189] group3/block1/conv1 output: [None, None, None, 512]
# [0819 13:54:08 @tensorpack_models.py:181] group3/block1/conv2 input: [None, None, None, 512]
# Use channels_last data format
# [0819 13:54:08 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:08 @tensorpack_models.py:189] group3/block1/conv2 output: [None, None, None, 512]
# [0819 13:54:08 @tensorpack_models.py:181] group3/block1/conv3 input: [None, None, None, 512]
# Use channels_last data format
# [0819 13:54:08 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:08 @tensorpack_models.py:189] group3/block1/conv3 output: [None, None, None, 2048]
# [0819 13:54:08 @tensorpack_models.py:181] group3/block2/conv1 input: [None, None, None, 2048]
# Use channels_last data format
# [0819 13:54:08 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:08 @tensorpack_models.py:189] group3/block2/conv1 output: [None, None, None, 512]
# [0819 13:54:08 @tensorpack_models.py:181] group3/block2/conv2 input: [None, None, None, 512]
# Use channels_last data format
# [0819 13:54:09 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:09 @tensorpack_models.py:189] group3/block2/conv2 output: [None, None, None, 512]
# [0819 13:54:09 @tensorpack_models.py:181] group3/block2/conv3 input: [None, None, None, 512]
# Use channels_last data format
# [0819 13:54:09 @tensorpack_models.py:855] WRN [BatchNorm] Using moving_mean/moving_variance in training.
# [0819 13:54:09 @tensorpack_models.py:189] group3/block2/conv3 output: [None, None, None, 2048]
# c2345 [<tf.Tensor 'transpose_2:0' shape=(None, 256, None, None) dtype=float16>, <tf.Tensor 'transpose_3:0' shape=(None, 512, None, None) dtype=float16>, <tf.Tensor 'transpose_4:0' shape=(None, 1024, None, None) dtype=float16>, <tf.Tensor 'transpose_5:0' shape=(None, 2048, None, None) dtype=float16>]
# [0819 13:54:09 @tensorpack_models.py:181] fpn input: [None, None, None, 256],[None, None, None, 512],[None, None, None, 1024],[None, None, None, 2048]
# [0819 13:54:09 @tensorpack_models.py:181] fpn/lateral_1x1_c2 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:09 @tensorpack_models.py:189] fpn/lateral_1x1_c2 output: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:181] fpn/lateral_1x1_c3 input: [None, None, None, 512]
# Use channels_last data format
# [0819 13:54:09 @tensorpack_models.py:189] fpn/lateral_1x1_c3 output: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:181] fpn/lateral_1x1_c4 input: [None, None, None, 1024]
# Use channels_last data format
# [0819 13:54:09 @tensorpack_models.py:189] fpn/lateral_1x1_c4 output: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:181] fpn/lateral_1x1_c5 input: [None, None, None, 2048]
# Use channels_last data format
# [0819 13:54:09 @tensorpack_models.py:189] fpn/lateral_1x1_c5 output: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:181] fpn/upsample_lat5 input: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:189] fpn/upsample_lat5 output: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:181] fpn/upsample_lat4 input: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:189] fpn/upsample_lat4 output: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:181] fpn/upsample_lat3 input: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:189] fpn/upsample_lat3 output: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:181] fpn/posthoc_3x3_p2 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:09 @tensorpack_models.py:189] fpn/posthoc_3x3_p2 output: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:181] fpn/posthoc_3x3_p3 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:09 @tensorpack_models.py:189] fpn/posthoc_3x3_p3 output: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:181] fpn/posthoc_3x3_p4 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:09 @tensorpack_models.py:189] fpn/posthoc_3x3_p4 output: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:181] fpn/posthoc_3x3_p5 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:09 @tensorpack_models.py:189] fpn/posthoc_3x3_p5 output: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:181] fpn/maxpool_p6 input: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:189] fpn/maxpool_p6 output: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:189] fpn output: [None, None, None, 256],[None, None, None, 256],[None, None, None, 256],[None, None, None, 256],[None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:181] rpn input: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:181] rpn/conv0 input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:09 @tensorpack_models.py:189] rpn/conv0 output: [None, None, None, 256]
# [0819 13:54:09 @tensorpack_models.py:181] rpn/class input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:09 @tensorpack_models.py:189] rpn/class output: [None, None, None, 3]
# [0819 13:54:09 @tensorpack_models.py:181] rpn/box input: [None, None, None, 256]
# Use channels_last data format
# [0819 13:54:09 @tensorpack_models.py:189] rpn/box output: [None, None, None, 12]
# [0819 13:54:09 @tensorpack_models.py:189] rpn output: [None, None, None, 3],[None, 12, None, None]
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# [0819 13:54:13 @tensorpack_models.py:181] fastrcnn input: [None, 256, 7, 7]
# WARNING:tensorflow:From ../MaskRCNN/model/boxclass_head.py:151: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# [0819 13:54:13 @tensorpack_models.py:181] fastrcnn/fc6 input: [None, 256, 7, 7]
# [0819 13:54:13 @tensorpack_models.py:189] fastrcnn/fc6 output: [None, 1024]
# [0819 13:54:13 @tensorpack_models.py:181] fastrcnn/fc7 input: [None, 1024]
# [0819 13:54:13 @tensorpack_models.py:189] fastrcnn/fc7 output: [None, 1024]
# [0819 13:54:13 @tensorpack_models.py:189] fastrcnn output: [None, 1024]
# [0819 13:54:13 @tensorpack_models.py:181] fastrcnn/outputs input: [None, 1024]
# [0819 13:54:13 @tensorpack_models.py:181] fastrcnn/outputs/class input: [None, 1024]
# [0819 13:54:13 @tensorpack_models.py:189] fastrcnn/outputs/class output: [None, 81]
# [0819 13:54:13 @tensorpack_models.py:181] fastrcnn/outputs/box input: [None, 1024]
# [0819 13:54:13 @tensorpack_models.py:189] fastrcnn/outputs/box output: [None, 324]
# [0819 13:54:13 @tensorpack_models.py:189] fastrcnn/outputs output: [None, 81],[None, 81, 4]
# [0819 13:54:13 @tensorpack_models.py:181] maskrcnn input: [None, 14, 14, 256]
# [0819 13:54:13 @tensorpack_models.py:181] maskrcnn/fcn0 input: [None, 14, 14, 256]
# Use channels_last data format
# [0819 13:54:13 @tensorpack_models.py:189] maskrcnn/fcn0 output: [None, 14, 14, 256]
# [0819 13:54:13 @tensorpack_models.py:181] maskrcnn/fcn1 input: [None, 14, 14, 256]
# Use channels_last data format
# [0819 13:54:13 @tensorpack_models.py:189] maskrcnn/fcn1 output: [None, 14, 14, 256]
# [0819 13:54:13 @tensorpack_models.py:181] maskrcnn/fcn2 input: [None, 14, 14, 256]
# Use channels_last data format
# [0819 13:54:14 @tensorpack_models.py:189] maskrcnn/fcn2 output: [None, 14, 14, 256]
# [0819 13:54:14 @tensorpack_models.py:181] maskrcnn/fcn3 input: [None, 14, 14, 256]
# Use channels_last data format
# [0819 13:54:14 @tensorpack_models.py:189] maskrcnn/fcn3 output: [None, 14, 14, 256]
# [0819 13:54:14 @tensorpack_models.py:181] maskrcnn/deconv input: [None, 14, 14, 256]
# [0819 13:54:14 @tensorpack_models.py:189] maskrcnn/deconv output: [None, 28, 28, 256]
# [0819 13:54:14 @tensorpack_models.py:181] maskrcnn/conv input: [None, 28, 28, 256]
# Use channels_last data format
# [0819 13:54:14 @tensorpack_models.py:189] maskrcnn/conv output: [None, 28, 28, 80]
# [0819 13:54:14 @tensorpack_models.py:189] maskrcnn output: [None, 80, 28, 28]
# WARNING:tensorflow:From ../MaskRCNN/model_box.py:195: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# INFO:tensorflow:Summary name mask_truth|pred is illegal; using mask_truth_pred instead.
# [0819 13:54:14 @tensorpack_models.py:702] regularize_cost() found 63 variables to regularize.
# [0819 13:54:14 @tensorpack_models.py:636] The following tensors will be regularized: group1/block0/conv1/W:0, group1/block0/conv2/W:0, group1/block0/conv3/W:0, group1/block0/convshortcut/W:0, group1/block1/conv1/W:0, group1/block1/conv2/W:0, group1/block1/conv3/W:0, group1/block2/conv1/W:0, group1/block2/conv2/W:0, group1/block2/conv3/W:0, group1/block3/conv1/W:0, group1/block3/conv2/W:0, group1/block3/conv3/W:0, group2/block0/conv1/W:0, group2/block0/conv2/W:0, group2/block0/conv3/W:0, group2/block0/convshortcut/W:0, group2/block1/conv1/W:0, group2/block1/conv2/W:0, group2/block1/conv3/W:0, group2/block2/conv1/W:0, group2/block2/conv2/W:0, group2/block2/conv3/W:0, group2/block3/conv1/W:0, group2/block3/conv2/W:0, group2/block3/conv3/W:0, group2/block4/conv1/W:0, group2/block4/conv2/W:0, group2/block4/conv3/W:0, group2/block5/conv1/W:0, group2/block5/conv2/W:0, group2/block5/conv3/W:0, group3/block0/conv1/W:0, group3/block0/conv2/W:0, group3/block0/conv3/W:0, group3/block0/convshortcut/W:0, group3/block1/conv1/W:0, group3/block1/conv2/W:0, group3/block1/conv3/W:0, group3/block2/conv1/W:0, group3/block2/conv2/W:0, group3/block2/conv3/W:0, fpn/lateral_1x1_c2/W:0, fpn/lateral_1x1_c3/W:0, fpn/lateral_1x1_c4/W:0, fpn/lateral_1x1_c5/W:0, fpn/posthoc_3x3_p2/W:0, fpn/posthoc_3x3_p3/W:0, fpn/posthoc_3x3_p4/W:0, fpn/posthoc_3x3_p5/W:0, rpn/conv0/W:0, rpn/class/W:0, rpn/box/W:0, fastrcnn/fc6/W:0, fastrcnn/fc7/W:0, fastrcnn/outputs/class/W:0, fastrcnn/outputs/box/W:0, maskrcnn/fcn0/W:0, maskrcnn/fcn1/W:0, maskrcnn/fcn2/W:0, maskrcnn/fcn3/W:0, maskrcnn/deconv/W:0, maskrcnn/conv/W:0
# TENSORPACK_FP16 set. Using FP16 loss scaling of 1024.0
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# [0819 13:54:22 @tensorpack_interface.py:175] Trainable Variables:
# name                                   shape                    dim
# -------------------------------------  ------------------  --------
# group1/block0/conv1/W:0                [1, 1, 256, 128]       32768
# group1/block0/conv1/bn/gamma:0         [128]                    128
# group1/block0/conv1/bn/beta:0          [128]                    128
# group1/block0/conv2/W:0                [3, 3, 128, 128]      147456
# group1/block0/conv2/bn/gamma:0         [128]                    128
# group1/block0/conv2/bn/beta:0          [128]                    128
# group1/block0/conv3/W:0                [1, 1, 128, 512]       65536
# group1/block0/conv3/bn/gamma:0         [512]                    512
# group1/block0/conv3/bn/beta:0          [512]                    512
# group1/block0/convshortcut/W:0         [1, 1, 256, 512]      131072
# group1/block0/convshortcut/bn/gamma:0  [512]                    512
# group1/block0/convshortcut/bn/beta:0   [512]                    512
# group1/block1/conv1/W:0                [1, 1, 512, 128]       65536
# group1/block1/conv1/bn/gamma:0         [128]                    128
# group1/block1/conv1/bn/beta:0          [128]                    128
# group1/block1/conv2/W:0                [3, 3, 128, 128]      147456
# group1/block1/conv2/bn/gamma:0         [128]                    128
# group1/block1/conv2/bn/beta:0          [128]                    128
# group1/block1/conv3/W:0                [1, 1, 128, 512]       65536
# group1/block1/conv3/bn/gamma:0         [512]                    512
# group1/block1/conv3/bn/beta:0          [512]                    512
# group1/block2/conv1/W:0                [1, 1, 512, 128]       65536
# group1/block2/conv1/bn/gamma:0         [128]                    128
# group1/block2/conv1/bn/beta:0          [128]                    128
# group1/block2/conv2/W:0                [3, 3, 128, 128]      147456
# group1/block2/conv2/bn/gamma:0         [128]                    128
# group1/block2/conv2/bn/beta:0          [128]                    128
# group1/block2/conv3/W:0                [1, 1, 128, 512]       65536
# group1/block2/conv3/bn/gamma:0         [512]                    512
# group1/block2/conv3/bn/beta:0          [512]                    512
# group1/block3/conv1/W:0                [1, 1, 512, 128]       65536
# group1/block3/conv1/bn/gamma:0         [128]                    128
# group1/block3/conv1/bn/beta:0          [128]                    128
# group1/block3/conv2/W:0                [3, 3, 128, 128]      147456
# group1/block3/conv2/bn/gamma:0         [128]                    128
# group1/block3/conv2/bn/beta:0          [128]                    128
# group1/block3/conv3/W:0                [1, 1, 128, 512]       65536
# group1/block3/conv3/bn/gamma:0         [512]                    512
# group1/block3/conv3/bn/beta:0          [512]                    512
# group2/block0/conv1/W:0                [1, 1, 512, 256]      131072
# group2/block0/conv1/bn/gamma:0         [256]                    256
# group2/block0/conv1/bn/beta:0          [256]                    256
# group2/block0/conv2/W:0                [3, 3, 256, 256]      589824
# group2/block0/conv2/bn/gamma:0         [256]                    256
# group2/block0/conv2/bn/beta:0          [256]                    256
# group2/block0/conv3/W:0                [1, 1, 256, 1024]     262144
# group2/block0/conv3/bn/gamma:0         [1024]                  1024
# group2/block0/conv3/bn/beta:0          [1024]                  1024
# group2/block0/convshortcut/W:0         [1, 1, 512, 1024]     524288
# group2/block0/convshortcut/bn/gamma:0  [1024]                  1024
# group2/block0/convshortcut/bn/beta:0   [1024]                  1024
# group2/block1/conv1/W:0                [1, 1, 1024, 256]     262144
# group2/block1/conv1/bn/gamma:0         [256]                    256
# group2/block1/conv1/bn/beta:0          [256]                    256
# group2/block1/conv2/W:0                [3, 3, 256, 256]      589824
# group2/block1/conv2/bn/gamma:0         [256]                    256
# group2/block1/conv2/bn/beta:0          [256]                    256
# group2/block1/conv3/W:0                [1, 1, 256, 1024]     262144
# group2/block1/conv3/bn/gamma:0         [1024]                  1024
# group2/block1/conv3/bn/beta:0          [1024]                  1024
# group2/block2/conv1/W:0                [1, 1, 1024, 256]     262144
# group2/block2/conv1/bn/gamma:0         [256]                    256
# group2/block2/conv1/bn/beta:0          [256]                    256
# group2/block2/conv2/W:0                [3, 3, 256, 256]      589824
# group2/block2/conv2/bn/gamma:0         [256]                    256
# group2/block2/conv2/bn/beta:0          [256]                    256
# group2/block2/conv3/W:0                [1, 1, 256, 1024]     262144
# group2/block2/conv3/bn/gamma:0         [1024]                  1024
# group2/block2/conv3/bn/beta:0          [1024]                  1024
# group2/block3/conv1/W:0                [1, 1, 1024, 256]     262144
# group2/block3/conv1/bn/gamma:0         [256]                    256
# group2/block3/conv1/bn/beta:0          [256]                    256
# group2/block3/conv2/W:0                [3, 3, 256, 256]      589824
# group2/block3/conv2/bn/gamma:0         [256]                    256
# group2/block3/conv2/bn/beta:0          [256]                    256
# group2/block3/conv3/W:0                [1, 1, 256, 1024]     262144
# group2/block3/conv3/bn/gamma:0         [1024]                  1024
# group2/block3/conv3/bn/beta:0          [1024]                  1024
# group2/block4/conv1/W:0                [1, 1, 1024, 256]     262144
# group2/block4/conv1/bn/gamma:0         [256]                    256
# group2/block4/conv1/bn/beta:0          [256]                    256
# group2/block4/conv2/W:0                [3, 3, 256, 256]      589824
# group2/block4/conv2/bn/gamma:0         [256]                    256
# group2/block4/conv2/bn/beta:0          [256]                    256
# group2/block4/conv3/W:0                [1, 1, 256, 1024]     262144
# group2/block4/conv3/bn/gamma:0         [1024]                  1024
# group2/block4/conv3/bn/beta:0          [1024]                  1024
# group2/block5/conv1/W:0                [1, 1, 1024, 256]     262144
# group2/block5/conv1/bn/gamma:0         [256]                    256
# group2/block5/conv1/bn/beta:0          [256]                    256
# group2/block5/conv2/W:0                [3, 3, 256, 256]      589824
# group2/block5/conv2/bn/gamma:0         [256]                    256
# group2/block5/conv2/bn/beta:0          [256]                    256
# group2/block5/conv3/W:0                [1, 1, 256, 1024]     262144
# group2/block5/conv3/bn/gamma:0         [1024]                  1024
# group2/block5/conv3/bn/beta:0          [1024]                  1024
# group3/block0/conv1/W:0                [1, 1, 1024, 512]     524288
# group3/block0/conv1/bn/gamma:0         [512]                    512
# group3/block0/conv1/bn/beta:0          [512]                    512
# group3/block0/conv2/W:0                [3, 3, 512, 512]     2359296
# group3/block0/conv2/bn/gamma:0         [512]                    512
# group3/block0/conv2/bn/beta:0          [512]                    512
# group3/block0/conv3/W:0                [1, 1, 512, 2048]    1048576
# group3/block0/conv3/bn/gamma:0         [2048]                  2048
# group3/block0/conv3/bn/beta:0          [2048]                  2048
# group3/block0/convshortcut/W:0         [1, 1, 1024, 2048]   2097152
# group3/block0/convshortcut/bn/gamma:0  [2048]                  2048
# group3/block0/convshortcut/bn/beta:0   [2048]                  2048
# group3/block1/conv1/W:0                [1, 1, 2048, 512]    1048576
# group3/block1/conv1/bn/gamma:0         [512]                    512
# group3/block1/conv1/bn/beta:0          [512]                    512
# group3/block1/conv2/W:0                [3, 3, 512, 512]     2359296
# group3/block1/conv2/bn/gamma:0         [512]                    512
# group3/block1/conv2/bn/beta:0          [512]                    512
# group3/block1/conv3/W:0                [1, 1, 512, 2048]    1048576
# group3/block1/conv3/bn/gamma:0         [2048]                  2048
# group3/block1/conv3/bn/beta:0          [2048]                  2048
# group3/block2/conv1/W:0                [1, 1, 2048, 512]    1048576
# group3/block2/conv1/bn/gamma:0         [512]                    512
# group3/block2/conv1/bn/beta:0          [512]                    512
# group3/block2/conv2/W:0                [3, 3, 512, 512]     2359296
# group3/block2/conv2/bn/gamma:0         [512]                    512
# group3/block2/conv2/bn/beta:0          [512]                    512
# group3/block2/conv3/W:0                [1, 1, 512, 2048]    1048576
# group3/block2/conv3/bn/gamma:0         [2048]                  2048
# group3/block2/conv3/bn/beta:0          [2048]                  2048
# fpn/lateral_1x1_c2/W:0                 [1, 1, 256, 256]       65536
# fpn/lateral_1x1_c2/b:0                 [256]                    256
# fpn/lateral_1x1_c3/W:0                 [1, 1, 512, 256]      131072
# fpn/lateral_1x1_c3/b:0                 [256]                    256
# fpn/lateral_1x1_c4/W:0                 [1, 1, 1024, 256]     262144
# fpn/lateral_1x1_c4/b:0                 [256]                    256
# fpn/lateral_1x1_c5/W:0                 [1, 1, 2048, 256]     524288
# fpn/lateral_1x1_c5/b:0                 [256]                    256
# fpn/posthoc_3x3_p2/W:0                 [3, 3, 256, 256]      589824
# fpn/posthoc_3x3_p2/b:0                 [256]                    256
# fpn/posthoc_3x3_p3/W:0                 [3, 3, 256, 256]      589824
# fpn/posthoc_3x3_p3/b:0                 [256]                    256
# fpn/posthoc_3x3_p4/W:0                 [3, 3, 256, 256]      589824
# fpn/posthoc_3x3_p4/b:0                 [256]                    256
# fpn/posthoc_3x3_p5/W:0                 [3, 3, 256, 256]      589824
# fpn/posthoc_3x3_p5/b:0                 [256]                    256
# rpn/conv0/W:0                          [3, 3, 256, 256]      589824
# rpn/conv0/b:0                          [256]                    256
# rpn/class/W:0                          [1, 1, 256, 3]           768
# rpn/class/b:0                          [3]                        3
# rpn/box/W:0                            [1, 1, 256, 12]         3072
# rpn/box/b:0                            [12]                      12
# fastrcnn/fc6/W:0                       [12544, 1024]       12845056
# fastrcnn/fc6/b:0                       [1024]                  1024
# fastrcnn/fc7/W:0                       [1024, 1024]         1048576
# fastrcnn/fc7/b:0                       [1024]                  1024
# fastrcnn/outputs/class/W:0             [1024, 81]             82944
# fastrcnn/outputs/class/b:0             [81]                      81
# fastrcnn/outputs/box/W:0               [1024, 324]           331776
# fastrcnn/outputs/box/b:0               [324]                    324
# maskrcnn/fcn0/W:0                      [3, 3, 256, 256]      589824
# maskrcnn/fcn0/b:0                      [256]                    256
# maskrcnn/fcn1/W:0                      [3, 3, 256, 256]      589824
# maskrcnn/fcn1/b:0                      [256]                    256
# maskrcnn/fcn2/W:0                      [3, 3, 256, 256]      589824
# maskrcnn/fcn2/b:0                      [256]                    256
# maskrcnn/fcn3/W:0                      [3, 3, 256, 256]      589824
# maskrcnn/fcn3/b:0                      [256]                    256
# maskrcnn/deconv/W:0                    [2, 2, 256, 256]      262144
# maskrcnn/deconv/b:0                    [256]                    256
# maskrcnn/conv/W:0                      [1, 1, 256, 80]        20480
# maskrcnn/conv/b:0                      [80]                      80
# Total #vars=168, #params=44175092, size=168.51MB
# [0819 13:54:22 @tensorpack_callbacks.py:1130] WRN logger directory was not set. Ignore TFEventWriter.
# [0819 13:54:22 @tensorpack_callbacks.py:1454] WRN logger directory was not set. Ignore JSONWriter.
# [0819 13:54:22 @tensorpack_interface.py:256] Setup callbacks graph ...
# [0819 13:54:22 @eval.py:482] Building pred graph on device /gpu:0...
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# c2345 [<tf.Tensor 'pred-0/transpose_2:0' shape=(None, 256, None, None) dtype=float16>, <tf.Tensor 'pred-0/transpose_3:0' shape=(None, 512, None, None) dtype=float16>, <tf.Tensor 'pred-0/transpose_4:0' shape=(None, 1024, None, None) dtype=float16>, <tf.Tensor 'pred-0/transpose_5:0' shape=(None, 2048, None, None) dtype=float16>]
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# Use channels_last data format
# loading annotations into memory...
# Done (t=1.74s)
# creating index...
# index created!
# [0819 13:54:33 @dataset.py:50] Instances loaded from /workspace/shared_workspace/data/coco/coco/annotations/instances_val2017.json.
# 100%|██████████| 5000/5000 [00:00<00:00, 170791.76it/s]
# [0819 13:54:33 @tensorpack_utils.py:349] Load Load annotations for val2017 finished, time:0.0358sec.
# [0819 13:54:33 @tensorpack_callbacks.py:1586] [MovingAverageSummary] 27 operations in collection 'MOVING_SUMMARY_OPS' will be run with session hooks.
# [0819 13:54:33 @tensorpack_callbacks.py:1632] Summarizing collection 'summaries' of size 30.
# [0819 13:54:37 @tensorpack_interface.py:325] Creating the session ...
# [0819 13:54:48 @tensorpack_interface.py:342] Initializing the session ...
# [0819 13:54:48 @tensorpack_tfutils.py:891] Variables to restore from dict: group2/block3/conv3/bn/beta:0, group2/block5/conv1/W:0, group2/block2/conv1/bn/variance/EMA:0, group3/block2/conv2/bn/beta:0, group3/block0/conv3/bn/mean/EMA:0, group1/block3/conv1/bn/gamma:0, group2/block0/conv3/W:0, group1/block3/conv2/W:0, group3/block0/conv2/bn/gamma:0, group1/block1/conv3/bn/mean/EMA:0, group1/block1/conv3/bn/beta:0, group3/block0/conv3/bn/beta:0, group2/block0/convshortcut/bn/gamma:0, group0/block1/conv2/bn/variance/EMA:0, group2/block0/conv1/bn/variance/EMA:0, group1/block0/conv3/bn/variance/EMA:0, group0/block2/conv1/bn/beta:0, group1/block0/conv2/bn/mean/EMA:0, group0/block2/conv3/bn/beta:0, group3/block2/conv3/bn/variance/EMA:0, group0/block1/conv2/bn/beta:0, group2/block5/conv3/bn/beta:0, group1/block0/conv1/bn/mean/EMA:0, group2/block0/convshortcut/bn/mean/EMA:0, group3/block1/conv3/W:0, group3/block0/conv3/bn/gamma:0, group1/block2/conv3/W:0, group2/block5/conv3/W:0, group0/block0/conv1/W:0, group1/block3/conv3/W:0, group0/block2/conv2/bn/beta:0, group1/block1/conv2/bn/mean/EMA:0, group1/block0/convshortcut/bn/gamma:0, group0/block1/conv1/W:0, group2/block0/conv2/bn/gamma:0, group2/block4/conv3/bn/gamma:0, group3/block0/convshortcut/W:0, group0/block1/conv3/bn/mean/EMA:0, group1/block1/conv2/bn/gamma:0, group1/block1/conv3/bn/gamma:0, group2/block1/conv3/bn/variance/EMA:0, group2/block0/convshortcut/W:0, group1/block0/conv1/bn/beta:0, group1/block0/conv2/bn/variance/EMA:0, group3/block1/conv2/W:0, group0/block1/conv1/bn/gamma:0, group2/block0/convshortcut/bn/variance/EMA:0, group1/block2/conv3/bn/mean/EMA:0, group0/block1/conv2/W:0, group2/block3/conv1/bn/mean/EMA:0, group0/block0/conv2/bn/gamma:0, group2/block3/conv2/W:0, group0/block0/conv3/bn/mean/EMA:0, group2/block1/conv2/bn/beta:0, group0/block1/conv1/bn/variance/EMA:0, group2/block4/conv3/bn/variance/EMA:0, group1/block0/conv3/bn/mean/EMA:0, group1/block2/conv2/W:0, group2/block3/conv1/bn/gamma:0, group2/block0/conv2/bn/variance/EMA:0, group1/block1/conv3/bn/variance/EMA:0, group2/block4/conv2/bn/variance/EMA:0, group2/block4/conv1/bn/mean/EMA:0, group1/block3/conv3/bn/variance/EMA:0, group1/block2/conv3/bn/beta:0, group3/block0/conv2/W:0, group2/block3/conv2/bn/variance/EMA:0, group0/block0/convshortcut/W:0, group1/block3/conv2/bn/mean/EMA:0, group2/block0/conv2/bn/mean/EMA:0, conv0/bn/beta:0, group1/block3/conv3/bn/gamma:0, group3/block0/conv2/bn/variance/EMA:0, group3/block2/conv1/bn/beta:0, group1/block0/conv3/W:0, group2/block1/conv3/W:0, group2/block0/conv3/bn/variance/EMA:0, group2/block3/conv3/bn/variance/EMA:0, group1/block3/conv2/bn/gamma:0, group2/block1/conv2/bn/variance/EMA:0, group0/block0/convshortcut/bn/variance/EMA:0, group2/block5/conv2/bn/mean/EMA:0, group1/block1/conv2/bn/beta:0, group2/block3/conv1/bn/beta:0, group0/block0/convshortcut/bn/mean/EMA:0, group2/block4/conv2/W:0, group3/block2/conv2/bn/gamma:0, group1/block0/conv3/bn/gamma:0, group2/block1/conv3/bn/beta:0, group2/block4/conv3/W:0, group0/block1/conv3/bn/variance/EMA:0, group0/block0/convshortcut/bn/beta:0, group2/block4/conv1/bn/gamma:0, group3/block2/conv3/W:0, group1/block3/conv1/bn/variance/EMA:0, group2/block1/conv2/bn/gamma:0, group1/block0/conv2/W:0, group2/block3/conv3/W:0, group1/block3/conv2/bn/beta:0, group3/block1/conv1/bn/variance/EMA:0, group3/block1/conv2/bn/mean/EMA:0, group3/block2/conv3/bn/beta:0, group0/block2/conv3/bn/gamma:0, group0/block1/conv2/bn/gamma:0, group1/block3/conv1/W:0, group0/block0/conv2/bn/beta:0, group2/block0/convshortcut/bn/beta:0, group2/block3/conv2/bn/gamma:0, group2/block2/conv2/bn/mean/EMA:0, group1/block1/conv3/W:0, group2/block4/conv3/bn/beta:0, group3/block0/conv3/W:0, group3/block0/conv1/bn/variance/EMA:0, group3/block2/conv2/bn/variance/EMA:0, group2/block5/conv1/bn/mean/EMA:0, group0/block1/conv2/bn/mean/EMA:0, group2/block3/conv1/W:0, group0/block0/conv3/bn/variance/EMA:0, group0/block2/conv1/bn/variance/EMA:0, group1/block0/conv1/bn/v ...
# [0819 13:54:48 @tensorpack_tfutils.py:604] WRN The following variables are in the graph, but not found in the dict: current_loss_scale, fastrcnn/fc6/W, fastrcnn/fc6/b, fastrcnn/fc7/W, fastrcnn/fc7/b, fastrcnn/outputs/box/W, fastrcnn/outputs/box/b, fastrcnn/outputs/class/W, fastrcnn/outputs/class/b, fpn/lateral_1x1_c2/W, fpn/lateral_1x1_c2/b, fpn/lateral_1x1_c3/W, fpn/lateral_1x1_c3/b, fpn/lateral_1x1_c4/W, fpn/lateral_1x1_c4/b, fpn/lateral_1x1_c5/W, fpn/lateral_1x1_c5/b, fpn/posthoc_3x3_p2/W, fpn/posthoc_3x3_p2/b, fpn/posthoc_3x3_p3/W, fpn/posthoc_3x3_p3/b, fpn/posthoc_3x3_p4/W, fpn/posthoc_3x3_p4/b, fpn/posthoc_3x3_p5/W, fpn/posthoc_3x3_p5/b, global_step, good_steps, learning_rate, maskrcnn/conv/W, maskrcnn/conv/b, maskrcnn/deconv/W, maskrcnn/deconv/b, maskrcnn/fcn0/W, maskrcnn/fcn0/b, maskrcnn/fcn1/W, maskrcnn/fcn1/b, maskrcnn/fcn2/W, maskrcnn/fcn2/b, maskrcnn/fcn3/W, maskrcnn/fcn3/b, rpn/box/W, rpn/box/b, rpn/class/W, rpn/class/b, rpn/conv0/W, rpn/conv0/b
# [0819 13:54:48 @tensorpack_tfutils.py:604] WRN The following variables are in the dict, but not found in the graph: linear/W, linear/b
# [0819 13:54:48 @tensorpack_tfutils.py:904] Restoring 265 variables from dict ...
# WARNING:tensorflow:From ../MaskRCNN/tensorpack_tfutils.py:751: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Prefer Variable.assign which has equivalent behavior in 2.X.
# [0819 13:55:48 @tensorpack_tfutils.py:747] WRN Variable group0/block0/convshortcut/W has dtype <dtype: 'float16'> but was given a value of dtype float32. Load it after downcasting!
# [0819 13:55:50 @tensorpack_tfutils.py:747] WRN Variable group0/block1/conv2/W has dtype <dtype: 'float16'> but was given a value of dtype float32. Load it after downcasting!
# [0819 13:56:23 @tensorpack_tfutils.py:747] WRN Variable group0/block2/conv3/W has dtype <dtype: 'float16'> but was given a value of dtype float32. Load it after downcasting!
# [0819 13:56:40 @tensorpack_tfutils.py:747] WRN Variable group0/block0/conv2/W has dtype <dtype: 'float16'> but was given a value of dtype float32. Load it after downcasting!
# [0819 13:56:43 @tensorpack_tfutils.py:747] WRN Variable conv0/W has dtype <dtype: 'float16'> but was given a value of dtype float32. Load it after downcasting!
# [0819 13:56:47 @tensorpack_tfutils.py:747] WRN Variable group0/block0/conv1/W has dtype <dtype: 'float16'> but was given a value of dtype float32. Load it after downcasting!
# [0819 13:57:05 @tensorpack_tfutils.py:747] WRN Variable group0/block2/conv1/W has dtype <dtype: 'float16'> but was given a value of dtype float32. Load it after downcasting!
# [0819 13:57:37 @tensorpack_tfutils.py:747] WRN Variable group0/block0/conv3/W has dtype <dtype: 'float16'> but was given a value of dtype float32. Load it after downcasting!
# [0819 13:58:26 @tensorpack_tfutils.py:747] WRN Variable group0/block1/conv3/W has dtype <dtype: 'float16'> but was given a value of dtype float32. Load it after downcasting!
# [0819 13:58:38 @tensorpack_tfutils.py:747] WRN Variable group0/block2/conv2/W has dtype <dtype: 'float16'> but was given a value of dtype float32. Load it after downcasting!
# [0819 13:59:58 @tensorpack_tfutils.py:747] WRN Variable group0/block1/conv1/W has dtype <dtype: 'float16'> but was given a value of dtype float32. Load it after downcasting!
# [0819 14:01:26 @tensorpack_interface.py:349] Graph Finalized.
# [0819 14:01:26 @tensorpack_interface.py:352] Broadcasting initialized variables ...
# [0819 14:01:28 @tensorpack_callbacks.py:1359] Starting EnqueueThread QueueInput/input_queue ...
# [0819 14:01:28 @tensorpack_callbacks.py:598] [HyperParamSetter] At global_step=0, learning_rate is set to 0.003333
# [0819 14:01:28 @tensorpack_callbacks.py:598] [HyperParamSetter] At global_step=0, learning_rate is set to 0.005000
# [0819 14:01:29 @eval.py:499] [EvalCallback] Will evaluate every 1 epochs
# [0819 14:01:29 @tensorpack_interface.py:444] Start Epoch 1 ...
#   0%|          |0/30000[00:00<?,?it/s]
# [0819 14:01:46 @tensorpack_callbacks.py:601] [HyperParamSetter] At global_step=1, learning_rate changes from 0.003333 to 0.003335
#   2%|1         |532/30000[03:18<2:28:45, 3.30it/s]
# [0819 14:04:48 @tensorpack_interface.py:465] Detected Ctrl-C and exiting main loop.
#   2%|1         |532/30000[03:18<3:03:24, 2.68it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-19c507578893> in <module>
# ----> 1 launch_train_with_config(traincfg)
#
# /workspace/shared_workspace/tensorpack/mask-rcnn-tensorflow/MaskRCNN/tensorpack_interface.py in launch_train_with_config(config)
#     451                         logger.info("Target accuracy has been reached, stop.....")
#     452                         return
# --> 453                     hooked_sess.run(train_op)
#     454                     _callbacks.trigger_step()
#     455                 _callbacks.after_epoch()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776         feed_dict=feed_dict,
#     777         options=options,
# --> 778         run_metadata=run_metadata)
#     779
#     780   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1281             feed_dict=feed_dict,
#    1282             options=options,
# -> 1283             run_metadata=run_metadata)
#    1284       except _PREEMPTION_ERRORS as e:
#    1285         logging.info(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1367   def run(self, *args, **kwargs):
#    1368     try:
# -> 1369       return self._sess.run(*args, **kwargs)
#    1370     except _PREEMPTION_ERRORS:
#    1371       raise
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1440         feed_dict=feed_dict,
#    1441         options=options,
# -> 1442         run_metadata=run_metadata)
#    1443
#    1444     for hook in self._hooks:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1198
#    1199   def run(self, *args, **kwargs):
# -> 1200     return self._sess.run(*args, **kwargs)
#    1201
#    1202   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     956     try:
#     957       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 958                          run_metadata_ptr)
#     959       if run_metadata:
#     960         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1179     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1180       results = self._do_run(handle, final_targets, final_fetches,
# -> 1181                              feed_dict_tensor, options, run_metadata)
#    1182     else:
#    1183       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
# [0819 14:04:49 @tensorpack_input_source.py:194] EnqueueThread QueueInput/input_queue Exited.
